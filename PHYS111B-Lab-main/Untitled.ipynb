# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("OPT Lab 85 Data.csv")
df1 = df[0:31]  #The last point is an outlier so it isn't considered
df1.columns
df1
# Out:
#     Mag Field (Gauss)  85 Mid Frequency  85 Min Frequency  85 Max Frequency  \
# 0              3.9800            3.0880            3.0860            3.0910
# 1              3.5300            2.7820            2.7810            2.7840
# 2              3.0900            2.4740            2.4740            2.4780
# 3              2.6500            2.1680            2.1660            2.1690
# 4              2.2100            1.8400            1.8380            1.8410
# 5              1.7700            1.5550            1.5530            1.5560
# 6              1.3300            1.2390            1.2370            1.2420
# 7              1.1000            1.0970            1.1040            1.0990
# 8              0.8840            0.9520            0.9490            0.9550
# 9              0.6630            0.7900            0.7870            0.7930
# 10             0.4420            0.6400            0.6360            0.6440
# 11             0.3530            0.3790            0.3780            0.3800
# 12             0.2650            0.3370            0.3357            0.3365
# 13             0.1770            0.2927            0.2922            0.2932
# 14             0.0884            0.2603            0.2599            0.2607
# 15             0.0000            0.2005            0.2001            0.2009
# 16             4.4200            3.3780            3.3720            3.3810
# 17             5.5200            4.1680            4.1650            4.1700
# 18             6.6300            4.9180            4.9140            4.9230
# 19             7.7300            5.7080            5.7030            5.7110
# 20            -3.9800            2.5020            2.4960            2.5060
# 21            -3.5300            2.1950            2.1930            2.1980
# 22            -3.0900            1.8990            1.8970            1.9020
# 23            -2.6500            1.6090            1.6060            1.6120
# 24            -2.2100            1.2880            1.2870            1.2900
# 25            -1.7700            0.9820            0.9790            0.9840
# 26            -1.3300            0.6590            0.6560            0.6630
# 27            -1.1000            0.5240            0.5230            0.5270
# 28            -0.8840            0.3730            0.3720            0.3760
# 29            -0.6630            0.1730            0.1720            0.1740
# 30            -4.4200            2.8020            2.8100            2.8070
#
#     Current (A)  Theoretical Frequency R^85
# 0          0.90                   2780000.0
# 1          0.80                   2470000.0
# 2          0.70                   2160000.0
# 3          0.60                   1850000.0
# 4          0.50                   1550000.0
# 5          0.40                   1240000.0
# 6          0.30                    927000.0
# 7          0.25                    773000.0
# 8          0.20                    618000.0
# 9          0.15                    464000.0
# 10         0.10                    309000.0
# 11         0.08                    247000.0
# 12         0.06                    185000.0
# 13         0.04                    124000.0
# 14         0.02                     61800.0
# 15         0.00                         0.0
# 16         1.00                   3090000.0
# 17         1.25                   3860000.0
# 18         1.50                   4640000.0
# 19         1.75                   5410000.0
# 20         0.90                   2780000.0
# 21         0.80                   2470000.0
# 22         0.70                   2160000.0
# 23         0.60                   1850000.0
# 24         0.50                   1550000.0
# 25         0.40                   1240000.0
# 26         0.30                    927000.0
# 27         0.25                    773000.0
# 28         0.20                    618000.0
# 29         0.15                    464000.0
# 30         1.00                   3090000.0

# %%
df2 = pd.read_csv("OPT Lab 87 Data.csv")
df2.columns
# Out:
# Index(['Mag Field (Gauss)', '87 Min Frequency', '87 Max Frequency',
#        '87 Mid Frequency', 'Current (A)', 'Theoretical Frequency R^87'],
#       dtype='object')
